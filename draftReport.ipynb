# %% [markdown]
# # Advisory report draft
# ___
# <pre>Teamname    : Submission Impossible 💥
# Group nr    : 32C
# Students    : {Andrei Dragomir, Ece Doganer, Márk Kerekes, Ariana Vargas Pastor}
# Student nrs : {2669304, 2552855, 2696796, 2710153}  </pre>
# ___

# %% [markdown]
# In this notebook you will find:
# 1. Data exploration together with its visualization
# 2. Modelling a Neural Network with single hidden layer and no drop-out on the data (TO COMPLETE)
# 3. Model evaluation and understanding (TODO)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
from turtle import title
import statistics
from scipy.stats import norm

# %% [markdown]
# ### Part 1: Exploration
#
# Visually explore the dataset, to get a feel for the information content and distributions of its features, and correlations between them. Visualise the data for your company, compared to overall population. What percentage of candidates is hired? How does this differ over gender, age, nationality, sports?
#
# We are expecting that higher degrees and higher university grade to have a higher impact on the success rate of candidates as well as the fact that they have received their degrees in the same field of interest as the company.

# %%
#Importing the dataset
recruitmentData = pd.read_csv (r'recruitmentdataset-2022-1.3.csv')
print(recruitmentData)
# Out:
#           Id  gender  age nationality     sport  ind-university_grade  \
# 0     x8011e  female   24      German  Swimming                    70
# 1     x6077a    male   26      German      Golf                    67
# 2     x6006e  female   23       Dutch   Running                    67
# 3     x2173b    male   24       Dutch   Cricket                    70
# 4     x6241a  female   26      German      Golf                    59
# ...      ...     ...  ...         ...       ...                   ...
# 3995  x7640e  female   28       Dutch   Running                    63
# 3996  x3310f  female   27       Dutch    Tennis                    62
# 3997  x1202g    male   24     Belgian     Rugby                    60
# 3998  x1263d  female   22       Dutch    Tennis                    66
# 3999  x2396a    male   28       Dutch  Football                    58
#
#       ind-debateclub  ind-programming_exp  ind-international_exp  \
# 0              False                False                  False
# 1              False                 True                  False
# 2              False                 True                   True
# 3              False                 True                  False
# 4              False                False                  False
# ...              ...                  ...                    ...
# 3995           False                False                  False
# 3996           False                False                  False
# 3997            True                False                  False
# 3998           False                 True                  False
# 3999           False                False                  False
#
#       ind-entrepeneur_exp  ind-languages  ind-exact_study ind-degree company  \
# 0                   False              1             True        phd       A
# 1                   False              2             True   bachelor       A
# 2                   False              0             True     master       A
# 3                   False              1             True     master       A
# 4                   False              1            False     master       A
# ...                   ...            ...              ...        ...     ...
# 3995                False              0            False     master       D
# 3996                 True              2             True   bachelor       D
# 3997                 True              2            False   bachelor       D
# 3998                False              1             True   bachelor       D
# 3999                False              1            False   bachelor       D
#
#       decision
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True
# ...        ...
# 3995     False
# 3996     False
# 3997     False
# 3998     False
# 3999     False
#
# [4000 rows x 15 columns]

# %%
dataC = pd.DataFrame(recruitmentData, columns = ['gender', 'age', 'nationality', 'sport', 'ind-university_grade', 'ind-debateclub', 'ind-programming_exp', 'ind-international_exp', 'ind-entrepeneur_exp', 'ind-languages', 'ind-exact_study', 'ind-degree', 'company', 'decision'])
dataC = dataC.query("company == 'C'")

fig, axs = plt.subplots(5,3)
fig.suptitle('DATA VISUALISATION FOR COMPANY C')
fig.set_figwidth(27)
fig.set_figheight(36)

axs[0, 0].set_title("Distribution of genders")
axs[0, 0].pie(dataC['gender']. value_counts(), labels = ['male', 'female', 'other'], autopct='%1.1f%%')
axs[0, 0].legend()

axs[0, 1].set_title("Distribution of age")
axs[0, 1].boxplot(dataC['age'], notch = True, showfliers = True)

axs[0, 2].set_title("Distribution of country of origin")
axs[0, 2].hist(dataC['nationality'], label = 'Candidates', bins = 3, orientation='horizontal')
axs[0, 2].legend()

axs[1, 0].set_title("Distribution of sports")
axs[1, 0].hist(dataC['sport'], orientation = 'vertical', bins = 8)

axs[1, 1].set_title("Distribution of university grades")
axs[1, 1].hist(dataC['ind-university_grade'], bins = 30)

axs[1, 2].set_title("Distribution of debate club participation")
axs[1, 2].pie(dataC['ind-debateclub'].value_counts(), labels = ['No debate experience', 'Debte experience'] , autopct='%1.1f%%')
axs[1, 2].legend()

axs[2, 0].set_title("Distribution of programming experience")
axs[2, 0].pie(dataC['ind-programming_exp'].value_counts(), labels = ['No programming experience', 'Programming experience'] , autopct='%1.1f%%')
axs[2, 0].legend()

axs[2, 1].set_title("Distribution of international experience")
axs[2, 1].pie(dataC['ind-international_exp'].value_counts(), labels = ['No international experience', 'International experience'] , autopct='%1.1f%%')
axs[2, 1].legend()

axs[2, 2].set_title("Distribution of entrepeneur experience")
axs[2, 2].pie(dataC['ind-entrepeneur_exp'].value_counts(), labels = ['No entrepeneur experience', 'Entrepeneur experience'] , autopct='%1.1f%%')
axs[2, 2].legend()

axs[3, 0].set_title("Distribution of languages")
axs[3, 0].hist(dataC['ind-languages'], bins = 8, align="mid")

axs[3, 1].set_title("Distribution of those who studied physics, engineering or other science-oriented study")
axs[3, 1].pie(dataC['ind-exact_study'].value_counts(), labels = ['Did not study', 'Studied'] , autopct='%1.1f%%')
axs[3, 1].legend()

axs[3, 2].set_title("Distribution of highest completed degree")
axs[3, 2].pie(dataC['ind-degree'].value_counts(), labels = ['Bachelor', 'Master', 'PHD'] , autopct='%1.1f%%')
axs[3, 2].legend()

axs[4, 0].set_visible(False)
axs[4, 2].set_visible(False)

axs[4, 1].set_title("Distribution of the hiring decision")
axs[4, 1].pie(dataC['decision'].value_counts(), labels = ['Not hired', 'Hired'] , autopct='%1.1f%%')
axs[4, 1].legend()

# %% [markdown]
# #### Demographic based analysis
#
# In this section we take into consideration the distribution of candidates based on _gender_ and _nationality_ and the difference in approval rates based on these traits.
#
# Observations:
# 1. We can observe that the majority of the candidates are of Dutch nationality;
# 2. We can observe that in all cases, the number of male candidates is higher than the female ones as well as the others;
# 3. We can observe that the positive decision rate is highest for male candidates which does not show much in itself given that the number of male candidates is considerably higher but more observations are made in the following sections

# %%
from cProfile import label

demographicDataFrame = pd.DataFrame(recruitmentData, columns = ['nationality', 'gender', 'decision', 'age', 'company'])

#TODO Visualize differences between demographic distribution of hired candidates in our company as opposed to the general hired population;
#     Every candidate that applied to our company compared with the company's hired population. - Andrei
# It is shown how the hired population of your company differs from the hired population overall and the population that applied to your company


fig1, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3,3)
fig1.suptitle('DEMOGRAPHIC DATA VISUALISATION')
fig1.set_figwidth(27)
fig1.set_figheight(27)

#First plot
demographicDataFrame.query("company == 'C' and decision == True")['gender'].value_counts().plot.pie(ax=ax1, labels=['male', 'female', 'other'], autopct='%1.1f%%')
ax1.set_title("Gender ratios of hired candidates within company C")
ax1.legend()

#Second plot
demographicDataFrame.query("company == 'C' and decision != True")['gender'].value_counts().plot.pie(ax=ax2, labels=['male', 'female', 'other'], autopct='%1.1f%%')
ax2.set_title("Gender ratios of failed candidates for company C")
ax2.legend()

#Third plot
demographicDataFrame.query("decision == True")['gender'].value_counts().plot.pie(ax=ax3, labels=['male', 'female', 'other'], autopct='%1.1f%%')
ax3.set_title("Gender ratios of hired candidates within all companies")
ax3.legend()

#Fourth plot
demographicDataFrame.query("decision and company != 'C'")['age'].plot(kind='density', ax=ax4, label="General hiree population ages")
demographicDataFrame.query("decision and company == 'C'")['age'].plot(kind='density', ax=ax4, label="Company C hiree ages")
ax4.set_xlabel("Age")
ax4.set_title("Age distributions in the general hiree poplation in comparison to our company's distrubutions")
ax4.legend()

#Fifth plot
demographicDataFrame.query("decision and company == 'C'")['age'].plot(kind='density', ax=ax5, label="Company C hiree ages")
demographicDataFrame.query("not decision and company == 'C'")['age'].plot(kind='density', ax=ax5, label="Company C rejectee ages")
ax5.set_xlabel("Age")
ax5.set_title("Age distributions of company C candidates")
ax5.legend()

#Sixth plot
demographicDataFrame.query("decision and company != 'C'")['age'].plot(kind='density', ax=ax6, label="General candidate population ages")
demographicDataFrame.query("not decision and company == 'C'")['age'].plot(kind='density', ax=ax6, label="Company C rejectee ages")
ax6.set_xlabel("Age")
ax6.set_title("Age distributions of company C candidates")
ax6.legend()

#Seventh plot
ax7.hist(demographicDataFrame['nationality'], label = 'Candidates', bins = 5, orientation='horizontal')
ax7.hist(demographicDataFrame.query("company == 'C'")['nationality'], bins = 5, label = 'Candidates of company C', orientation='horizontal', alpha = 0.75)
ax7.set_title("Candidate distribution based on nationality")
ax7.legend()

#Eighth plot
ax8.hist(demographicDataFrame.query("gender == 'male' and company == 'C'")['nationality'], label='Male Candidates', orientation='horizontal', align='mid', alpha= 0.75)
ax8.hist(demographicDataFrame.query("gender == 'female' and company == 'C'")['nationality'], label='Female Candidates', orientation='horizontal', align='left', alpha= 0.75)
ax8.hist(demographicDataFrame.query("gender == 'other' and company == 'C'")['nationality'], label='Other Candidates', orientation='horizontal', align='right', alpha= 0.75)
ax8.set_title("Candidate distribution based on nationality split on genders")
ax8.legend()



#Ninth plot
ax9.hist(demographicDataFrame.query("decision and company != 'C'")['gender'], bins = 5, label = 'Rejectees of company C', orientation='horizontal', alpha = 0.75)
ax9.hist(demographicDataFrame.query("decision and company == 'C'")['gender'], label = 'Hirees of company C', bins = 5, orientation='horizontal', alpha=0.75)
ax9.set_title("Candidate distribution based on genders")
ax9.legend()

# %% [markdown]
# Success rate of candidates for company C, based on gender.

# %%
maleDataFrame = demographicDataFrame.query("gender == 'male' and company == 'C'")
maleSuccessRate = (maleDataFrame[maleDataFrame['decision']].value_counts()/ maleDataFrame['decision'].count()) * 100

femaleDataFrame = demographicDataFrame.query("gender == 'female' and company == 'C'")
femaleSuccessRate = (femaleDataFrame[femaleDataFrame['decision']].value_counts()/ femaleDataFrame['decision'].count()) * 100

otherDataFrame = demographicDataFrame.query("gender == 'other' and company == 'C'")
otherSuccessRate = (otherDataFrame[otherDataFrame['decision']].value_counts()/ otherDataFrame['decision'].count()) * 100

print("Male cummulative success rate: " + str(maleSuccessRate.sum()))
print("Female cummulative success rate: " + str(femaleSuccessRate.sum()))
print("Others cummulative success rate: " + str(otherSuccessRate.sum()))
# Out:
# Male cummulative success rate: 27.67175572519084
# Female cummulative success rate: 23.399558498896248
# Others cummulative success rate: 30.434782608695656

# %% [markdown]
# The following section will focus on the analysis of professional and academic levels of the candidates and how that affects their success rate

# %%
professionalDataFrame = pd.DataFrame(recruitmentData, columns = ['ind-exact_study', 'ind-university_grade', 'ind-programming_experience', 'ind-degree', 'decision', 'company'])

professionalDataFrame.rename(columns={'ind-university_grade': 'grade', 'ind-programming_experience': 'experience', 'ind-degree': 'degree', 'ind-exact_study' : 'study'}, inplace=True)

fig, ((ax1, ax2, ax3)) = plt.subplots(1,3)
fig.suptitle('PROFESSIONAL DATA VISUALISATION')
fig.set_figwidth(27)
fig.set_figheight(9)

ax1.hist(professionalDataFrame.query("decision and company == 'C'")['degree'], align='left', label="Hirees education level in company C")
ax1.hist(professionalDataFrame.query("decision and company == 'A'")['degree'], align='right', label="Hirees education level in company A")
ax1.set_title("Candidate distribution based on nationality split on genders")
ax1.legend()

ax2.hist(professionalDataFrame.query("decision and company == 'C'")['degree'], align='left',label="Hirees education level in company C")
ax2.hist(professionalDataFrame.query("decision and company == 'B'")['degree'], align='right',label="Hirees education level in company B")
ax2.set_title("Candidate distribution based on nationality split on genders")
ax2.legend()

ax3.hist(professionalDataFrame.query("decision and company == 'C'")['degree'], align='left', label="Hirees education level in company C")
ax3.hist(professionalDataFrame.query("decision and company == 'D'")['degree'], align='right', label="Hirees education level in company D")
ax3.set_title("Candidate distribution based on nationality split on genders")
ax3.legend()

fig, ((ax1, ax2, ax3, ax4)) = plt.subplots(1,4)
fig.set_figwidth(27)
fig.set_figheight(9)

professionalDataFrame.query("decision and company == 'A'")['grade'].plot(kind='box', ax=ax1, label="Company A hiree grade distribution")
ax1.set_title("Distribution of grades in company A")
ax1.set_ylim(45,80)

professionalDataFrame.query("decision and company == 'B'")['grade'].plot(kind='box', ax=ax2, label="Company B hiree grade distribution")
ax2.set_title("Distribution of grades in company B")
ax2.set_ylim(45,80)

professionalDataFrame.query("decision and company == 'C'")['grade'].plot(kind='box', ax=ax3, label="Company C hiree grade distribution")
ax3.set_title("Distribution of grades in company C")
ax3.set_ylim(45,80)

professionalDataFrame.query("decision and company == 'D'")['grade'].plot(kind='box', ax=ax4, label="Company D hiree grade distribution")
ax4.set_title("Distribution of grades in company D")
ax4.set_ylim(45,80)
# Out:
# (45.0, 80.0)

# %%
#Explicit grade distribution and statistical information also shown in the first box plot above
professionalDataFrame.query("decision and company == 'C'")['grade'].describe()
# Out:
# count    258.000000
# mean      61.972868
# std        5.731614
# min       51.000000
# 25%       58.000000
# 50%       62.000000
# 75%       66.000000
# max       77.000000
# Name: grade, dtype: float64

# %% [markdown]
# Correlations between the different predictors and between the predictors and indicators

# %%
df = pd.DataFrame(recruitmentData, columns = ["Id", "gender", "age", "nationality", "sport", "ind-university_grade", "ind-debateclub", "ind-programming_exp", "ind-international_exp", "ind-entrepeneur_exp", "ind-languages", "ind-exact_study", "ind-degree", "company", "decision"])
df_C = df[df["company"] == 'C']
corr = df_C.corr()
seaborn.heatmap(corr, mask=np.zeros_like(corr), cmap=seaborn.diverging_palette(220, 10, as_cmap=True),
            square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ranking for the predictive power of the indicators

# %%
ranking = corr['decision']
ranking = ranking.sort_values()
ranking.name = "Ranking of the predictive power of indicators"
print(ranking)
# Out:
# ind-exact_study         -0.194558
# ind-programming_exp     -0.159530
# ind-university_grade    -0.037285
# ind-entrepeneur_exp      0.027853
# ind-debateclub           0.033267
# ind-languages            0.132866
# age                      0.194080
# ind-international_exp    0.406178
# decision                 1.000000
# Name: Ranking of the predictive power of indicators, dtype: float64

# %% [markdown]
# ### M1: Neural Network with a single hidden layer and no drop-out (NOT FUNCTIONAL YET)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#Importing the dataset as a dataframe
df = pd.read_csv (r'recruitmentdataset-2022-1.3.csv')
df.columns = ['Id', 'gender', 'age', 'nat', 'sport', 'grade', 'debclub', 'progxp', 'intxp', 'entrxp', 'lang', 'exactStudy', 'degree', 'comp', 'hired']

# %% [markdown]
# #### Prepairing data for modelling

# %% [markdown]
# #### Splitting the data
#
# We decided to split the entire data set with a 80/20 split.

# %%
#splitting dataset: independent var x, dependent var y
x = pd.DataFrame(df.iloc[:, [8, 2, 10, 6]].values)
y = df.iloc[:, 14].values

x.loc[:, 0] = LabelEncoder().fit_transform(x.iloc[:, 0])
x.loc[:, 3] = LabelEncoder().fit_transform(x.iloc[:, 3])

print(x)
#splitting dataset: training and test set, where 80% of the data is in the training set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

#feature scaling
vsc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

#initializing ANN
classifier = Sequential()

#adding the input layer and hidden layer
#TODO : try diff activation
classifier.add(Dense(6, kernel_initializer='uniform', activation = 'relu', input_dim = 4))
#output layer
classifier.add(Dense(1, kernel_initializer='uniform', activation = 'sigmoid'))

classifier.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
classifier.fit(x_train, y_train, validation_split=0.33, epochs=150, batch_size=10)
# Out:
#       0   1  2  3
# 0     0  24  1  0
# 1     0  26  2  0
# 2     1  23  0  0
# 3     0  24  1  0
# 4     0  26  1  0
# ...  ..  .. .. ..
# 3995  0  28  0  0
# 3996  0  27  2  0
# 3997  0  24  2  1
# 3998  0  22  1  0
# 3999  0  28  1  0
#
# [4000 rows x 4 columns]
# Epoch 1/150
# 215/215 [==============================] - 1s 2ms/step - loss: 0.6581 - accuracy: 0.6884 - val_loss: 0.6128 - val_accuracy: 0.6686
# Epoch 2/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5779 - accuracy: 0.6889 - val_loss: 0.5796 - val_accuracy: 0.6686
# Epoch 3/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5624 - accuracy: 0.6936 - val_loss: 0.5771 - val_accuracy: 0.6809
# Epoch 4/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5579 - accuracy: 0.7076 - val_loss: 0.5745 - val_accuracy: 0.6894
# Epoch 5/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5545 - accuracy: 0.7118 - val_loss: 0.5732 - val_accuracy: 0.6866
# Epoch 6/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5519 - accuracy: 0.7099 - val_loss: 0.5724 - val_accuracy: 0.6847
# Epoch 7/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5501 - accuracy: 0.7141 - val_loss: 0.5719 - val_accuracy: 0.6875
# Epoch 8/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5484 - accuracy: 0.7122 - val_loss: 0.5705 - val_accuracy: 0.6875
# Epoch 9/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5467 - accuracy: 0.7094 - val_loss: 0.5704 - val_accuracy: 0.6847
# Epoch 10/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5454 - accuracy: 0.7104 - val_loss: 0.5705 - val_accuracy: 0.6875
# Epoch 11/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5442 - accuracy: 0.7108 - val_loss: 0.5694 - val_accuracy: 0.6847
# Epoch 12/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5431 - accuracy: 0.7127 - val_loss: 0.5685 - val_accuracy: 0.6847
# Epoch 13/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5422 - accuracy: 0.7108 - val_loss: 0.5689 - val_accuracy: 0.6847
# Epoch 14/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5414 - accuracy: 0.7104 - val_loss: 0.5691 - val_accuracy: 0.6847
# Epoch 15/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5410 - accuracy: 0.7118 - val_loss: 0.5691 - val_accuracy: 0.6875
# Epoch 16/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5403 - accuracy: 0.7122 - val_loss: 0.5687 - val_accuracy: 0.6847
# Epoch 17/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5398 - accuracy: 0.7122 - val_loss: 0.5687 - val_accuracy: 0.6875
# Epoch 18/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5395 - accuracy: 0.7122 - val_loss: 0.5685 - val_accuracy: 0.6875
# Epoch 19/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5389 - accuracy: 0.7104 - val_loss: 0.5686 - val_accuracy: 0.6875
# Epoch 20/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5386 - accuracy: 0.7146 - val_loss: 0.5683 - val_accuracy: 0.6847
# Epoch 21/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5383 - accuracy: 0.7141 - val_loss: 0.5692 - val_accuracy: 0.6875
# Epoch 22/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5381 - accuracy: 0.7118 - val_loss: 0.5681 - val_accuracy: 0.6847
# Epoch 23/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5378 - accuracy: 0.7108 - val_loss: 0.5694 - val_accuracy: 0.6866
# Epoch 24/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5376 - accuracy: 0.7085 - val_loss: 0.5697 - val_accuracy: 0.6875
# Epoch 25/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5374 - accuracy: 0.7136 - val_loss: 0.5693 - val_accuracy: 0.6875
# Epoch 26/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5373 - accuracy: 0.7085 - val_loss: 0.5685 - val_accuracy: 0.6875
# Epoch 27/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5373 - accuracy: 0.7113 - val_loss: 0.5688 - val_accuracy: 0.6837
# Epoch 28/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5369 - accuracy: 0.7141 - val_loss: 0.5694 - val_accuracy: 0.6866
# Epoch 29/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5369 - accuracy: 0.7122 - val_loss: 0.5685 - val_accuracy: 0.6875
# Epoch 30/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5369 - accuracy: 0.7080 - val_loss: 0.5700 - val_accuracy: 0.6875
# Epoch 31/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5366 - accuracy: 0.7160 - val_loss: 0.5704 - val_accuracy: 0.6856
# Epoch 32/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5368 - accuracy: 0.7127 - val_loss: 0.5698 - val_accuracy: 0.6837
# Epoch 33/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5367 - accuracy: 0.7132 - val_loss: 0.5699 - val_accuracy: 0.6866
# Epoch 34/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5366 - accuracy: 0.7080 - val_loss: 0.5699 - val_accuracy: 0.6866
# Epoch 35/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5365 - accuracy: 0.7127 - val_loss: 0.5699 - val_accuracy: 0.6837
# Epoch 36/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5363 - accuracy: 0.7118 - val_loss: 0.5700 - val_accuracy: 0.6856
# Epoch 37/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5366 - accuracy: 0.7127 - val_loss: 0.5693 - val_accuracy: 0.6866
# Epoch 38/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5363 - accuracy: 0.7122 - val_loss: 0.5694 - val_accuracy: 0.6866
# Epoch 39/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5364 - accuracy: 0.7122 - val_loss: 0.5692 - val_accuracy: 0.6875
# Epoch 40/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5363 - accuracy: 0.7104 - val_loss: 0.5700 - val_accuracy: 0.6847
# Epoch 41/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5361 - accuracy: 0.7122 - val_loss: 0.5701 - val_accuracy: 0.6847
# Epoch 42/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5361 - accuracy: 0.7118 - val_loss: 0.5696 - val_accuracy: 0.6875
# Epoch 43/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5361 - accuracy: 0.7113 - val_loss: 0.5702 - val_accuracy: 0.6875
# Epoch 44/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5360 - accuracy: 0.7136 - val_loss: 0.5698 - val_accuracy: 0.6847
# Epoch 45/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7122 - val_loss: 0.5694 - val_accuracy: 0.6875
# Epoch 46/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7094 - val_loss: 0.5702 - val_accuracy: 0.6847
# Epoch 47/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5360 - accuracy: 0.7122 - val_loss: 0.5700 - val_accuracy: 0.6866
# Epoch 48/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7146 - val_loss: 0.5702 - val_accuracy: 0.6866
# Epoch 49/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5360 - accuracy: 0.7108 - val_loss: 0.5701 - val_accuracy: 0.6847
# Epoch 50/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7118 - val_loss: 0.5703 - val_accuracy: 0.6866
# Epoch 51/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7132 - val_loss: 0.5699 - val_accuracy: 0.6761
# Epoch 52/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7080 - val_loss: 0.5703 - val_accuracy: 0.6847
# Epoch 53/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7132 - val_loss: 0.5709 - val_accuracy: 0.6780
# Epoch 54/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7108 - val_loss: 0.5712 - val_accuracy: 0.6828
# Epoch 55/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7127 - val_loss: 0.5702 - val_accuracy: 0.6875
# Epoch 56/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7136 - val_loss: 0.5702 - val_accuracy: 0.6790
# Epoch 57/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7090 - val_loss: 0.5702 - val_accuracy: 0.6761
# Epoch 58/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7099 - val_loss: 0.5702 - val_accuracy: 0.6761
# Epoch 59/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7122 - val_loss: 0.5704 - val_accuracy: 0.6847
# Epoch 60/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7146 - val_loss: 0.5711 - val_accuracy: 0.6866
# Epoch 61/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5361 - accuracy: 0.7076 - val_loss: 0.5703 - val_accuracy: 0.6828
# Epoch 62/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7132 - val_loss: 0.5702 - val_accuracy: 0.6818
# Epoch 63/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7136 - val_loss: 0.5706 - val_accuracy: 0.6866
# Epoch 64/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7076 - val_loss: 0.5708 - val_accuracy: 0.6866
# Epoch 65/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7132 - val_loss: 0.5703 - val_accuracy: 0.6818
# Epoch 66/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7127 - val_loss: 0.5698 - val_accuracy: 0.6780
# Epoch 67/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7146 - val_loss: 0.5701 - val_accuracy: 0.6780
# Epoch 68/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7160 - val_loss: 0.5700 - val_accuracy: 0.6780
# Epoch 69/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7113 - val_loss: 0.5707 - val_accuracy: 0.6780
# Epoch 70/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7122 - val_loss: 0.5703 - val_accuracy: 0.6761
# Epoch 71/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7136 - val_loss: 0.5704 - val_accuracy: 0.6780
# Epoch 72/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7132 - val_loss: 0.5706 - val_accuracy: 0.6799
# Epoch 73/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7141 - val_loss: 0.5698 - val_accuracy: 0.6780
# Epoch 74/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7155 - val_loss: 0.5705 - val_accuracy: 0.6780
# Epoch 75/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7108 - val_loss: 0.5698 - val_accuracy: 0.6780
# Epoch 76/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7174 - val_loss: 0.5694 - val_accuracy: 0.6790
# Epoch 77/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7146 - val_loss: 0.5699 - val_accuracy: 0.6761
# Epoch 78/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7113 - val_loss: 0.5707 - val_accuracy: 0.6866
# Epoch 79/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7108 - val_loss: 0.5706 - val_accuracy: 0.6761
# Epoch 80/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7113 - val_loss: 0.5701 - val_accuracy: 0.6780
# Epoch 81/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7136 - val_loss: 0.5702 - val_accuracy: 0.6780
# Epoch 82/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7094 - val_loss: 0.5699 - val_accuracy: 0.6780
# Epoch 83/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7094 - val_loss: 0.5695 - val_accuracy: 0.6780
# Epoch 84/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7122 - val_loss: 0.5709 - val_accuracy: 0.6761
# Epoch 85/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7127 - val_loss: 0.5707 - val_accuracy: 0.6799
# Epoch 86/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7118 - val_loss: 0.5701 - val_accuracy: 0.6780
# Epoch 87/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7141 - val_loss: 0.5697 - val_accuracy: 0.6790
# Epoch 88/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7108 - val_loss: 0.5703 - val_accuracy: 0.6761
# Epoch 89/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7122 - val_loss: 0.5703 - val_accuracy: 0.6761
# Epoch 90/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7108 - val_loss: 0.5701 - val_accuracy: 0.6780
# Epoch 91/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7104 - val_loss: 0.5700 - val_accuracy: 0.6780
# Epoch 92/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7155 - val_loss: 0.5700 - val_accuracy: 0.6809
# Epoch 93/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7113 - val_loss: 0.5693 - val_accuracy: 0.6799
# Epoch 94/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7113 - val_loss: 0.5704 - val_accuracy: 0.6790
# Epoch 95/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7136 - val_loss: 0.5701 - val_accuracy: 0.6780
# Epoch 96/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7113 - val_loss: 0.5702 - val_accuracy: 0.6799
# Epoch 97/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7118 - val_loss: 0.5704 - val_accuracy: 0.6761
# Epoch 98/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7155 - val_loss: 0.5696 - val_accuracy: 0.6799
# Epoch 99/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7141 - val_loss: 0.5697 - val_accuracy: 0.6799
# Epoch 100/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7118 - val_loss: 0.5700 - val_accuracy: 0.6761
# Epoch 101/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7108 - val_loss: 0.5699 - val_accuracy: 0.6761
# Epoch 102/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7132 - val_loss: 0.5705 - val_accuracy: 0.6780
# Epoch 103/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7085 - val_loss: 0.5694 - val_accuracy: 0.6780
# Epoch 104/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7150 - val_loss: 0.5695 - val_accuracy: 0.6771
# Epoch 105/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7136 - val_loss: 0.5701 - val_accuracy: 0.6790
# Epoch 106/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7094 - val_loss: 0.5701 - val_accuracy: 0.6790
# Epoch 107/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7141 - val_loss: 0.5711 - val_accuracy: 0.6780
# Epoch 108/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7090 - val_loss: 0.5706 - val_accuracy: 0.6790
# Epoch 109/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7118 - val_loss: 0.5709 - val_accuracy: 0.6780
# Epoch 110/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7150 - val_loss: 0.5700 - val_accuracy: 0.6780
# Epoch 111/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7136 - val_loss: 0.5699 - val_accuracy: 0.6799
# Epoch 112/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7113 - val_loss: 0.5701 - val_accuracy: 0.6790
# Epoch 113/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7108 - val_loss: 0.5706 - val_accuracy: 0.6780
# Epoch 114/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7094 - val_loss: 0.5696 - val_accuracy: 0.6790
# Epoch 115/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7113 - val_loss: 0.5703 - val_accuracy: 0.6780
# Epoch 116/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7127 - val_loss: 0.5702 - val_accuracy: 0.6780
# Epoch 117/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7136 - val_loss: 0.5695 - val_accuracy: 0.6799
# Epoch 118/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7090 - val_loss: 0.5705 - val_accuracy: 0.6780
# Epoch 119/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7122 - val_loss: 0.5700 - val_accuracy: 0.6761
# Epoch 120/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7127 - val_loss: 0.5697 - val_accuracy: 0.6790
# Epoch 121/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7136 - val_loss: 0.5705 - val_accuracy: 0.6780
# Epoch 122/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7113 - val_loss: 0.5702 - val_accuracy: 0.6761
# Epoch 123/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7136 - val_loss: 0.5700 - val_accuracy: 0.6780
# Epoch 124/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7132 - val_loss: 0.5706 - val_accuracy: 0.6780
# Epoch 125/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7132 - val_loss: 0.5706 - val_accuracy: 0.6780
# Epoch 126/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7141 - val_loss: 0.5705 - val_accuracy: 0.6780
# Epoch 127/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7104 - val_loss: 0.5703 - val_accuracy: 0.6780
# Epoch 128/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7136 - val_loss: 0.5701 - val_accuracy: 0.6780
# Epoch 129/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7118 - val_loss: 0.5700 - val_accuracy: 0.6790
# Epoch 130/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7094 - val_loss: 0.5703 - val_accuracy: 0.6790
# Epoch 131/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5354 - accuracy: 0.7136 - val_loss: 0.5700 - val_accuracy: 0.6780
# Epoch 132/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7146 - val_loss: 0.5708 - val_accuracy: 0.6780
# Epoch 133/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7099 - val_loss: 0.5699 - val_accuracy: 0.6809
# Epoch 134/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7146 - val_loss: 0.5702 - val_accuracy: 0.6780
# Epoch 135/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7164 - val_loss: 0.5705 - val_accuracy: 0.6780
# Epoch 136/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7127 - val_loss: 0.5706 - val_accuracy: 0.6799
# Epoch 137/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7150 - val_loss: 0.5701 - val_accuracy: 0.6761
# Epoch 138/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7132 - val_loss: 0.5700 - val_accuracy: 0.6799
# Epoch 139/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7127 - val_loss: 0.5698 - val_accuracy: 0.6799
# Epoch 140/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7127 - val_loss: 0.5699 - val_accuracy: 0.6780
# Epoch 141/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5354 - accuracy: 0.7132 - val_loss: 0.5705 - val_accuracy: 0.6799
# Epoch 142/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7099 - val_loss: 0.5705 - val_accuracy: 0.6780
# Epoch 143/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7146 - val_loss: 0.5704 - val_accuracy: 0.6780
# Epoch 144/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7113 - val_loss: 0.5705 - val_accuracy: 0.6780
# Epoch 145/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7118 - val_loss: 0.5704 - val_accuracy: 0.6780
# Epoch 146/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7141 - val_loss: 0.5697 - val_accuracy: 0.6799
# Epoch 147/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7132 - val_loss: 0.5699 - val_accuracy: 0.6761
# Epoch 148/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7108 - val_loss: 0.5698 - val_accuracy: 0.6780
# Epoch 149/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5357 - accuracy: 0.7141 - val_loss: 0.5710 - val_accuracy: 0.6780
# Epoch 150/150
# 215/215 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.7132 - val_loss: 0.5700 - val_accuracy: 0.6780
